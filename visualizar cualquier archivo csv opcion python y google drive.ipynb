# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f84b0ece-31b1-44b2-95f5-76d8df3e2c90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f84b0ece-31b1-44b2-95f5-76d8df3e2c90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

# Accessing the uploaded file with the correct name from the uploaded dictionary
file_name = list(uploaded.keys())[0]  # Get the actual name of the uploaded file
df = pd.read_csv(io.BytesIO(uploaded[file_name]))

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
#     Año    Mes Departamento Subsistema                                Ciclo  \
# 0  2019  Marzo     Paysandu      DGEIP                  Primaria 2do. Ciclo
# 1  2019  Marzo    Lavalleja      DGEIP                  Primaria 1er. Ciclo
# 2  2019  Marzo      Florida      DGEIP                  Primaria 1er. Ciclo
# 3  2019  Marzo    Maldonado      DGETP  Articulacion Educacion Media Basica
# 4  2019  Marzo     Paysandu       DGES                         Bachillerato
#
#    UsuariosCREA  UsuariosMAT  UsuariosBiblioteca
# 0           797          364                  51
# 1             0            1                   0
# 2             0            0                   0
# 3             0            0                   0
# 4           394            1                 272

# %%
from IPython.display import display

display(df)
# Out:
#         Año    Mes    Departamento Subsistema  \
# 0      2019  Marzo        Paysandu      DGEIP
# 1      2019  Marzo       Lavalleja      DGEIP
# 2      2019  Marzo         Florida      DGEIP
# 3      2019  Marzo       Maldonado      DGETP
# 4      2019  Marzo        Paysandu       DGES
# ...     ...    ...             ...        ...
# 38193  2025  Marzo           Salto      DGETP
# 38194  2025  Marzo        San Jose      DGETP
# 38195  2025  Marzo         Soriano      DGETP
# 38196  2025  Marzo      Tacuarembo      DGETP
# 38197  2025  Marzo  Treinta Y Tres      DGETP
#
#                                      Ciclo  UsuariosCREA  UsuariosMAT  \
# 0                      Primaria 2do. Ciclo           797          364
# 1                      Primaria 1er. Ciclo             0            1
# 2                      Primaria 1er. Ciclo             0            0
# 3      Articulacion Educacion Media Basica             0            0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# Lee el archivo (ajusta la ruta)
df = pd.read_csv('/content/drive/MyDrive/ruta/a/tu_archivo.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-8-70a27fb5e842> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 # Lee el archivo (ajusta la ruta)
#       5 df = pd.read_csv('/content/drive/MyDrive/ruta/a/tu_archivo.csv')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# ...
