# %% [markdown]
# <a href="https://colab.research.google.com/github/freakezoide/codigos-de-coolab/blob/main/visualizar_cualquier_csv_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the pandas library with the alias 'pd'
import pandas as pd

# Ejemplo con un archivo en GitHub
url_github = "https://raw.githubusercontent.com/freakezoide/archivos-csv/refs/heads/main/datos_docentes_2019.csv"
df = pd.read_csv(url_github)
display(df.head())
# Out:
#    Id persona       Sexo      Rol Departamento Subsistema  Año lectivo  \
# 0        6651   Femenino  Docente   Tacuarembo       DGES         2019
# 1        9251  Masculino  Docente      Florida       DGES         2019
# 2        9569   Femenino  Docente      Florida       DGES         2019
# 3        9629   Femenino  Docente    Canelones      DGEIP         2019
# 4        9674   Femenino  Docente    Canelones      DGEIP         2019
#
#    Cantidad de días ingreso a CREA  Cantidad de Comentarios posteados  \
# 0                                0                                  0
# 1                                9                                  0
# 2                                4                                  0
# 3                               48                                 14
# 4                               65                                  0
#
#    Cantidad de Acciones totales  Cantidad de días de ingreso a Biblioteca  \
# ...
